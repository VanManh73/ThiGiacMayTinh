# %%
from PIL import Image
from imgtools import *

# %%
dir = 'C:/Users/HP/thigiacmaytinh/img'

# %%
imgs = get_image_list(dir)
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (711, 521)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=711x521>
# (1200, 630)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x630>
# (732, 732)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=732x732>
# (225, 225)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>
# (800, 800)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800>
# (711, 521)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=711x521>
# (711, 521)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=711x521>
