# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\hp\anaconda3\lib\site-packages (10.3.0)

# %%
# Thêm thư viện
from PIL import Image

# %%
dir = 'C:/Users/HP/thigiacmaytinh/img'

# %%
image_path = dir + "/1.JPG"
print(image_path)
# Out:
# C:/Users/HP/thigiacmaytinh/img/1.JPG

# %%
img01 = Image.open(image_path)

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=711x521>

# %%
# In thông tin cơ bản 
print("định dạng : " + img01.format)
# Out:
# định dạng : JPEG

# %%
print("kích thước ảnh : ", img01.size)
# Out:
# kích thước ảnh :  (711, 521)

# %%
new_img_01_path = dir + '/MANH_01.JPG'
new_img_PNG_01_path = dir + '/MANH_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_PNG_01_path)
